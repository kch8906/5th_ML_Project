# %%
# !git clone https://github.com/ultralytics/yolov3
# !cd yolov3;pip install -qr requirements.txt
# Out:
# fatal: destination path 'yolov3' already exists and is not an empty directory.
# /bin/bash: line 0: cd: /home/crysis/Desktop/yolov3: No such file or directory
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !wget -O incredibles.zip https://github.com/chulminkw/DLCV/blob/master/incredibles.zip?raw=true
# !mkdir /home/crysis/Desktop/incredibles
# !unzip incredibles.zip -d /home/crysis/Desktop/incredibles
# Out:
# --2022-04-24 23:53:03--  https://github.com/chulminkw/DLCV/blob/master/incredibles.zip?raw=true
# Resolving github.com (github.com)... 15.164.81.167
# Connecting to github.com (github.com)|15.164.81.167|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/chulminkw/DLCV/raw/master/incredibles.zip [following]
# --2022-04-24 23:53:03--  https://github.com/chulminkw/DLCV/raw/master/incredibles.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/chulminkw/DLCV/master/incredibles.zip [following]
# --2022-04-24 23:53:03--  https://raw.githubusercontent.com/chulminkw/DLCV/master/incredibles.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# ...

# %%
# !wget -O /home/crysis/Desktop/incredibles/incredibles.yaml https://raw.githubusercontent.com/chulminkw/DLCV/master/data/util/incredibles.yaml
# Out:
# /home/crysis/Downloads/eyes/eyes.yaml: Scheme missing.

# %%
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: changhyun (use `wandb login --relogin` to force relogin)
# True

# %%
import matplotlib.pyplot as plt
img_color = plt.imread('/home/crysis/Desktop/eyes/images/train/closed eyes people_15.jpg')
plt.imshow(img_color)
plt.show()
img_color.shape
# Out:
# (252, 200, 3)

# %%
# !cd /home/crysis/Downloads/yolov3; python train.py --img 640 --batch 4 --epochs 150 --data /home/crysis/Desktop/eyes/eyes.yaml --weights yolov3.pt \
                                                   --project=/home/crysis/Desktop/eyes/eyes_w --name eyes --exist-ok
# Out:
# wandb: Currently logged in as: changhyun (use `wandb login --relogin` to force relogin)
# train: weights=yolov3.pt, cfg=, data=/home/crysis/Desktop/eyes/eyes.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=150, batch_size=4, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=/home/crysis/Desktop/eyes/eyes_w, name=eyes, exist_ok=True, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov3
# YOLOv3 🚀 2022-4-20 torch 1.11.0+cu102 CUDA:0 (NVIDIA GeForce RTX 2060, 5927MiB)
#
# ...

# %% [markdown]
# ### 단일 이미지 및 Video inference 수행

# %%
# image 파일 inference 
# !cd /home/crysis/Downloads/yolov3;python detect.py --source /home/crysis/Desktop/eyes/images/train/closed_eyes_people_0.jpg \
                            --weights /home/crysis/Desktop/eyes/eyes_w/eyes/weights/best.pt --conf 0.3 \
                            --project=/home/crysis/Desktop/eyes/output --name=run_image --exist-ok --line-thickness 2
# Out:
# detect: weights=['/home/crysis/Desktop/eyes/eyes_w/eyes/weights/best.pt'], source=/home/crysis/Desktop/eyes/images/train/closed_eyes_people_0.jpg, imgsz=[640, 640], conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/home/crysis/Desktop/eyes/output, name=run_image, exist_ok=True, line_thickness=2, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv3 🚀 2022-4-20 torch 1.11.0+cu102 CUDA:0 (NVIDIA GeForce RTX 2060, 5927MiB)
#
# Fusing layers...
# Model Summary: 261 layers, 61502815 parameters, 0 gradients, 154.7 GFLOPs
# image 1/1 /home/crysis/Desktop/eyes/images/train/closed_eyes_people_0.jpg: 480x640 1 closed, Done. (0.037s)
# Speed: 0.8ms pre-process, 36.6ms inference, 1.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /home/crysis/Desktop/eyes/output/run_image

# %%
from IPython.display import Image, clear_output 
Image(filename='/home/crysis/Desktop/eyes/output/run_image/closed_eyes_people_0.jpg', width=300)

# %%
# !cd /home/crysis/Downloads/yolov3;python detect.py --source /home/crysis/Desktop/eyes/sleep.mp4 \
                            --weights /home/crysis/Desktop/eyes/eyes_w/eyes/weights/best.pt --conf 0.3 \
                            --project=/home/crysis/Desktop/eyes/output --name=run_image --exist-ok --line-thickness 2
# Out:
# detect: weights=['/home/crysis/Desktop/eyes/eyes_w/eyes/weights/best.pt'], source=/home/crysis/Desktop/eyes/sleep.mp4, imgsz=[640, 640], conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/home/crysis/Desktop/eyes/output, name=run_image, exist_ok=True, line_thickness=2, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv3 🚀 2022-4-20 torch 1.11.0+cu102 CUDA:0 (NVIDIA GeForce RTX 2060, 5927MiB)
#
# Fusing layers...
# Model Summary: 261 layers, 61502815 parameters, 0 gradients, 154.7 GFLOPs
# video 1/1 (1/1475) /home/crysis/Desktop/eyes/sleep.mp4: 384x640 Done. (0.029s)
# video 1/1 (2/1475) /home/crysis/Desktop/eyes/sleep.mp4: 384x640 Done. (0.027s)
# video 1/1 (3/1475) /home/crysis/Desktop/eyes/sleep.mp4: 384x640 Done. (0.029s)
# ...
